# %% [markdown]
# # Download dataasets

# %%
from datasets import load_dataset
from huggingface_hub import login
from huggingface_hub import whoami

login(token="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")

# %% [markdown]
# ## viet_bud500 (500h)

# %%
from datasets import load_dataset

# Login using e.g. `huggingface-cli login` to access this dataset
ds = load_dataset(
    "linhtran92/viet_bud500",
    cache_dir="E:/PROJECTS/Vietnamese_History_Chatbot/datasets/audio_datasets/"
)

# %% [markdown]
# ## FPT Open Speech Vietnamese dataset

# %%
fpt_open_speech_folder = "E:/PROJECTS/Vietnamese_History_Chatbot/datasets/audio_datasets/mp3"
fpt_script_path = "E:/PROJECTS/Vietnamese_History_Chatbot/datasets/audio_datasets/transcriptAll.txt"

# %% [markdown]
# # Load model Whisper

# %%
whisper_small = "E:/PROJECTS/Vietnamese_History_Chatbot/audio_models/whisper/small.pt"
